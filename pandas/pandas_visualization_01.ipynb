# %% [markdown]
# # Some plotting w/ pandas.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
DATASET = '/Users/dantohe/Development/Projects/Springboard/datasets/aapl/aapl.csv'
aapl = pd.read_csv(DATASET, index_col='date',parse_dates = True)
aapl.info()
aapl.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3270 entries, 2000-03-01 to 2013-03-01
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3270 non-null   int64
#  1   adj_close   3270 non-null   float64
#  2   close       3270 non-null   float64
#  3   high        3270 non-null   float64
#  4   low         3270 non-null   float64
#  5   open        3270 non-null   float64
#  6   volume      3270 non-null   int64
# dtypes: float64(5), int64(2)
# memory usage: 204.4 KB
#             Unnamed: 0  adj_close   close    high     low    open    volume
# date
# 2000-03-01           0      31.68  130.31  132.06  118.50  118.56  38478000
# 2000-03-02           1      29.66  122.00  127.94  120.69  127.00  11136800
# 2000-03-03           2      31.12  128.00  128.23  120.00  124.87  11565200
# 2000-03-06           3      30.56  125.69  129.13  125.00  126.00   7520000
# ...

# %%
close_arr = aapl['close'].values
type(close_arr)
# Out:
# numpy.ndarray

# %%
plt.plot(close_arr)
plt.show()

# %%
#plotting it as a series
plt.plot(aapl['close'])
plt.show()
type(aapl['close'])
# Out:
# pandas.core.series.Series

# %%
#the built in function
aapl['close'].plot()
plt.show()

# %%
aapl.plot()
plt.show()

# %%
plt.plot(aapl)

# %%
aapl.plot()
plt.yscale('log')
plt.show()

# %%
aapl['open'].plot(color='b',style='.-',legend=True)
aapl['close'].plot(color='r',style='.',legend=True)
plt.axis(('2001','2002',0,100))
plt.show()

# %%
aapl['close'].plot(color='r',style='.',legend=True)
plt.axis(('2001','2002',0,100))
plt.show()

# %%
aapl.loc['2001':'2004', ['open','close','high','low']].plot()
plt.show()
plt.savefig('aapl.png')

# %%
# !pwd
# Out:
# /Users/dantohe/Development/Projects/Springboard/jupyter/springboard_work
